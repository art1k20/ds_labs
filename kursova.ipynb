# %%
import pandas as pd
file = r"COVID-19 Coronavirus.csv"
df = pd.read_csv(file, index_col='Country')
df.isnull().sum()
# Out:
# Other names                1
# ISO 3166-1 alpha-3 CODE    0
# Population                 0
# Continent                  0
# Total Cases                0
# Total Deaths               0
# Tot Cases//1M pop          0
# Tot Deaths/1M pop          0
# Death percentage           0
# dtype: int64

# %%
df
# Out:
#                                  Other names ISO 3166-1 alpha-3 CODE  \
# Country
# Afghanistan                      Afghanistan                     AFG
# Albania                              Albania                     ALB
# Algeria                              Algeria                     DZA
# Andorra                              Andorra                     AND
# Angola                                Angola                     AGO
# ...                                      ...                     ...
# Wallis and Futuna  Wallis and Futuna Islands                     WLF
# Western Sahara                Western Sahara                   ESHÂ
# Yemen                                  Yemen                     YEM
# Zambia                                Zambia                     ZMB
# Zimbabwe                            Zimbabwe                     ZWE
#
#                    Population Continent  Total Cases  Total Deaths  \
# Country
# ...

# %%
df_1 = df[:10][['Total Cases', 'Total Deaths', 'Tot Cases//1M pop', 'Tot Deaths/1M pop']]
df_1.style.highlight_max(color='green').highlight_min(color='red')
# Out:
# <style type="text/css">
# #T_5a059_row3_col2, #T_5a059_row7_col0, #T_5a059_row7_col1, #T_5a059_row8_col3 {
#   background-color: green;
# }
# #T_5a059_row4_col2, #T_5a059_row4_col3, #T_5a059_row5_col0, #T_5a059_row5_col1 {
#   background-color: red;
# }
# </style>
# <table id="T_5a059">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5a059_level0_col0" class="col_heading level0 col0" >Total Cases</th>
#       <th id="T_5a059_level0_col1" class="col_heading level0 col1" >Total Deaths</th>
#       <th id="T_5a059_level0_col2" class="col_heading level0 col2" >Tot Cases//1M pop</th>
#       <th id="T_5a059_level0_col3" class="col_heading level0 col3" >Tot Deaths/1M pop</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Country</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
# ...

# %%
df.mean()
# Out:
# C:\Users\valer\AppData\Local\Temp\ipykernel_13556\3698961737.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# Population           3.507321e+07
# Total Cases          2.184781e+06
# Total Deaths         2.744813e+04
# Tot Cases//1M pop    1.369004e+05
# Tot Deaths/1M pop    1.096716e+03
# Death percentage     1.444125e+00
# dtype: float64

# %%
df.var()
# Out:
# C:\Users\valer\AppData\Local\Temp\ipykernel_13556\1568254755.py:1: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.var()
# Population           1.938829e+16
# Total Cases          5.293927e+13
# Total Deaths         9.388015e+09
# Tot Cases//1M pop    2.104250e+10
# Tot Deaths/1M pop    1.429736e+06
# Death percentage     3.033617e+00
# dtype: float64
